# %%
import requests

url =  "https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-01-01T14%3A01%3A01UTC/fechafin/2022-01-30T14%3A01%3A01UTC/todasestaciones"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtYWxleGFuZHJhLm92YWxsZXNAZ21haWwuY29tIiwianRpIjoiMjFhOWExNzYtYjcwNS00NmI0LTljNWMtZDYzMzg1NWE4NjAxIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3MDk5MTY2MzUsInVzZXJJZCI6IjIxYTlhMTc2LWI3MDUtNDZiNC05YzVjLWQ2MzM4NTVhODYwMSIsInJvbGUiOiIifQ.BBcH6AHMOrLEPMlKXRD3xhQmKgOYSPpdo7W7i16l_AE"}

headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

resultado=response.json()
resultado


##ahora hay que hacer una llamada a request para descargar los datos
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/b5fa4e21',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}

# %%
response = requests.request("GET", "https://opendata.aemet.es/opendata/sh/b5fa4e21", headers=headers, params=querystring)

response.json()
datos=response.json()

# %%
import pandas as pd

# %%
data=pd.DataFrame(datos)
data
# Out:
#             fecha indicativo                nombre              provincia  \
# 0      2022-01-02      C439J                GÜÍMAR  STA. CRUZ DE TENERIFE
# 1      2022-01-02      0255B         SANTA SUSANNA              BARCELONA
# 2      2022-01-02      5612B  LA RODA DE ANDALUCÍA                SEVILLA
# 3      2022-01-02      3094B              TARANCÓN                 CUENCA
# 4      2022-01-02      9394X             CALATAYUD               ZARAGOZA
# ...           ...        ...                   ...                    ...
# 21496  2022-01-30      7211B      PUERTO LUMBRERAS                 MURCIA
# 21497  2022-01-30      7138B               JUMILLA                 MURCIA
# 21498  2022-01-30      7103Y               TOBARRA               ALBACETE
# 21499  2022-01-30      7127X                BULLAS                 MURCIA
# 21500  2022-01-30      8018X             ELX/ELCHE               ALICANTE
#
#       altitud  tmed prec  tmin horatmin  tmax  ... presMax horaPresMax  \
# ...

# %% [markdown]
# ### Test 2

# %%
##NO TOCAR- ESTA ES LA BASE PARA LA EXTRACCION

import requests
from datetime import datetime, timedelta
import pandas as pd



start_date="2024-02-01T09%3A00%3A00UTC"
end_date="2024-02-30T09%3A00%3A00UTC"
url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{start_date}/fechafin/{end_date}/todasestaciones"

api = {"api_key": "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtYWxleGFuZHJhLm92YWxsZXNAZ21haWwuY29tIiwianRpIjoiMjFhOWExNzYtYjcwNS00NmI0LTljNWMtZDYzMzg1NWE4NjAxIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3MDk5MTY2MzUsInVzZXJJZCI6IjIxYTlhMTc2LWI3MDUtNDZiNC05YzVjLWQ2MzM4NTVhODYwMSIsInJvbGUiOiIifQ.BBcH6AHMOrLEPMlKXRD3xhQmKgOYSPpdo7W7i16l_AE"}




response = requests.request("GET", url, headers=headers, params=api)
resultado=response.json() ##Esta es la respuesta al request a AEMET, de aquí sale el link a los datos
final_link=resultado.get("datos")
final_link

respuesta=requests.request("GET",final_link,headers=headers,params=api)
datos=respuesta.json()

df=pd.DataFrame(datos)

# %%
#INTENTEMOS HACER HACER UN LOOP
startdate = "2024-03-01T09%3A00%3A00UTC"
enddate="2024-03-23T09%3A00%3A00UTC"

# %%
from datetime import datetime

coded_sdate= datetime.strptime(startdate, "%Y-%m-%dT%H%%3A%M%%3A%SUTC")
coded_edate= datetime.strptime(enddate, "%Y-%m-%dT%H%%3A%M%%3A%SUTC")
# Out:
# datetime.datetime(2024, 3, 23, 9, 0)

# %%
startdate = "2024-03-01T09%3A00%3A00UTC"
enddate="2024-03-30T09%3A00%3A00UTC"


i=0
while i <=120: ##max120

    url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{startdate}/fechafin/{enddate}/todasestaciones"
    api = {"api_key": "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtYWxleGFuZHJhLm92YWxsZXNAZ21haWwuY29tIiwianRpIjoiMjFhOWExNzYtYjcwNS00NmI0LTljNWMtZDYzMzg1NWE4NjAxIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3MDk5MTY2MzUsInVzZXJJZCI6IjIxYTlhMTc2LWI3MDUtNDZiNC05YzVjLWQ2MzM4NTVhODYwMSIsInJvbGUiOiIifQ.BBcH6AHMOrLEPMlKXRD3xhQmKgOYSPpdo7W7i16l_AE"}
    response = requests.request("GET", url, headers=headers, params=api)
    resultado=response.json() ##Esta es la respuesta al request a AEMET, de aquí sale el link a los datos
    final_link=resultado.get("datos")
    respuesta=requests.request("GET",final_link,headers=headers,params=api)
    data=pd.DataFrame(respuesta.json())

    if i==0:
        datosf=pd.DataFrame(data)
    else:
        datosf=pd.concat([datosf,data],axis=0)
    coded_stime = datetime.strptime(startdate, "%Y-%m-%dT%H%%3A%M%%3A%SUTC")
    ncoded_stime=coded_stime-timedelta(days=30)
    startdate=ncoded_stime.strftime("%Y-%m-%dT%H%%3A%M%%3A%SUTC")
    coded_etime = datetime.strptime(enddate, "%Y-%m-%dT%H%%3A%M%%3A%SUTC")
    ncoded_etime=coded_etime-timedelta(days=30)
    enddate=ncoded_etime.strftime("%Y-%m-%dT%H%%3A%M%%3A%SUTC")
    i=i+1

# %%
datosf.to_csv('/Users/mariaalexandraovalles/Desktop/TFM/datosfinales.csv')

# %%
df=pd.read_csv('datosfinales.csv')
df
# Out:
#          Unnamed: 0       fecha indicativo                    nombre  \
# 0                 0  2024-03-02      8293X                    XÀTIVA
# 1                 1  2024-03-02      2400E          AUTILLA DEL PINO
# 2                 2  2024-03-02      5612B      LA RODA DE ANDALUCÍA
# 3                 3  2024-03-02      2755X                 BENAVENTE
# 4                 4  2024-03-02      C249I  FUERTEVENTURA AEROPUERTO
# ...             ...         ...        ...                       ...
# 2544168       20458  2014-05-22      7211B          PUERTO LUMBRERAS
# 2544169       20459  2014-05-22      7138B                   JUMILLA
# 2544170       20460  2014-05-22      7103Y                   TOBARRA
# 2544171       20461  2014-05-22      7127X                    BULLAS
# 2544172       20462  2014-05-22      8018X                 ELX/ELCHE
#
#           provincia  altitud  tmed prec  tmin horatmin  ... presMax  \
# 0          VALENCIA       88  13,9  3,4   7,3    22:20  ...  1003,8
# ...

# %%
df['fecha'].nunique()
# Out:
# 3499
